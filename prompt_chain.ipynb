# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0.01)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate an detailed outline for a blog on a topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '## Blog Outline: The Rise of AI in India - A Transformative Journey\n\n**I. Introduction: The Dawn of an Intelligent Era in India**\n\n*   **A. Hook:** Start with a compelling statistic, a futuristic vision, or a relatable anecdote about AI\'s growing presence in India.\n    *   *Example Hook:* "From smart assistants in our homes to AI-powered diagnostics in hospitals, Artificial Intelligence is no longer a distant dream for India; it\'s a rapidly unfolding reality."\n*   **B. Defining AI (Briefly):** A concise, non-technical explanation of what AI is and its core capabilities (learning, problem-solving, decision-making).\n*   **C. Thesis Statement:** Clearly state the blog\'s main argument – that India is experiencing a significant and transformative rise in AI adoption and development, driven by various factors and poised to reshape its economy and society.\n*   **D. Roadmap:** Briefly outline what the reader can expect to learn from the blog (key drivers, sectors impacted, challenges, future outlook).\n\n**II. The Catalysts: Why India is Embracing AI**\n\n*   **A. Government Initiatives and Policy Support:**\n    *   1. **National Strategy for AI:** Discuss key government policies and frameworks (e.g., NITI Aayog\'s AI strategy, Digital India).\n    *   2. **Funding and Investment:** Highlight government grants, R&D funding, and incentives for AI startups.\n    *   3. **Focus on "AI for All":** Emphasize the government\'s vision of inclusive AI development for societal benefit.\n*   **B. Thriving Tech Ecosystem and Talent Pool:**\n    *   1. **Growing Startup Culture:** Showcase the vibrant Indian startup scene and its increasing focus on AI solutions.\n    *   2. **Skilled Workforce:** Discuss the availability of a large, young, and increasingly skilled workforce in STEM fields.\n    *   3. **Educational Institutions:** Mention the role of universities and research institutions in fostering AI talent and research.\n*   **C. Digital Transformation and Data Availability:**\n    *   1. **Increased Internet Penetration and Smartphone Usage:** Explain how widespread digital access fuels data generation.\n    *   2. **Digital India and Data Infrastructure:** Discuss the impact of initiatives like Aadhaar and UPI on creating a data-rich environment.\n    *   3. **Growing Data Volumes:** Emphasize the sheer amount of data being generated in India, crucial for AI training.\n*   **D. Economic Imperatives and Global Competitiveness:**\n    *   1. **Need for Efficiency and Productivity Gains:** How AI can address India\'s economic challenges.\n    *   2. **Global AI Race:** India\'s ambition to be a leader in the global AI landscape.\n    *   3. **Attracting Foreign Investment:** How AI capabilities make India an attractive destination for global tech giants.\n\n**III. AI in Action: Transforming Key Sectors in India**\n\n*   **A. Healthcare:**\n    *   1. **Diagnostics and Imaging:** AI for early disease detection (cancer, diabetic retinopathy).\n    *   2. **Drug Discovery and Development:** Accelerating research and personalized medicine.\n    *   3. **Robotic Surgery and Patient Care:** Enhancing surgical precision and improving patient outcomes.\n    *   4. **Telemedicine and Remote Healthcare:** AI-powered solutions for rural and underserved areas.\n*   **B. Agriculture:**\n    *   1. **Precision Farming:** AI for crop monitoring, yield prediction, and resource optimization (water, fertilizer).\n    *   2. **Pest and Disease Detection:** Early identification and management of agricultural threats.\n    *   3. **Supply Chain Optimization:** Improving efficiency from farm to fork.\n*   **C. Finance and Banking (FinTech):**\n    *   1. **Fraud Detection and Risk Management:** AI for enhanced security and compliance.\n    *   2. **Personalized Financial Advice and Robo-Advisors:** Democratizing financial planning.\n    *   3. **Credit Scoring and Loan Underwriting:** Improving access to cr ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline: The Rise of AI in India - A Transformative Journey
#
# **I. Introduction: The Dawn of an Intelligent Era in India**
#
# *   **A. Hook:** Start with a compelling statistic, a futuristic vision, or a relatable anecdote about AI's growing presence in India.
#     *   *Example Hook:* "From smart assistants in our homes to AI-powered diagnostics in hospitals, Artificial Intelligence is no longer a distant dream for India; it's a rapidly unfolding reality."
# *   **B. Defining AI (Briefly):** A concise, non-technical explanation of what AI is and its core capabilities (learning, problem-solving, decision-making).
# *   **C. Thesis Statement:** Clearly state the blog's main argument – that India is experiencing a significant and transformative rise in AI adoption and development, driven by various factors and poised to reshape its economy and society.
# *   **D. Roadmap:** Briefly outline what the reader can expect to learn from the blog (key drivers, sectors impacted, challenges, future outlook).
#
# **II. The Catalysts: Why India is Embracing AI**
#
# *   **A. Government Initiatives and Policy Support:**
#     *   1. **National Strategy for AI:** Discuss key government policies and frameworks (e.g., NITI Aayog's AI strategy, Digital India).
#     *   2. **Funding and Investment:** Highlight government grants, R&D funding, and incentives for AI startups.
#     *   3. **Focus on "AI for All":** Emphasize the government's vision of inclusive AI development for societal benefit.
# *   **B. Thriving Tech Ecosystem and Talent Pool:**
#     *   1. **Growing Startup Culture:** Showcase the vibrant Indian startup scene and its increasing focus on AI solutions.
#     *   2. **Skilled Workforce:** Discuss the availability of a large, young, and increasingly skilled workforce in STEM fields.
#     *   3. **Educational Institutions:** Mention the role of universities and research institutions in fostering AI talent and research.
# *   **C. Digital Transformation and Data Availability:**
#     *   1. **Increased Internet Penetration and Smartphone Usage:** Explain how widespread digital access fuels data generation.
#     *   2. **Digital India and Data Infrastructure:** Discuss the impact of initiatives like Aadhaar and UPI on creating a data-rich environment.
#     *   3. **Growing Data Volumes:** Emphasize the sheer amount of data being generated in India, crucial for AI training.
# *   **D. Economic Imperatives and Global Competitiveness:**
#     *   1. **Need for Efficiency and Productivity Gains:** How AI can address India's economic challenges.
#     *   2. **Global AI Race:** India's ambition to be a leader in the global AI landscape.
#     *   3. **Attracting Foreign Investment:** How AI capabilities make India an attractive destination for global tech giants.
#
# **III. AI in Action: Transforming Key Sectors in India**
#
# *   **A. Healthcare:**
#     *   1. **Diagnostics and Imaging:** AI for early disease detection (cancer, diabetic retinopathy).
#     *   2. **Drug Discovery and Development:** Accelerating research and personalized medicine.
#     *   3. **Robotic Surgery and Patient Care:** Enhancing surgical precision and improving patient outcomes.
#     *   4. **Telemedicine and Remote Healthcare:** AI-powered solutions for rural and underserved areas.
# *   **B. Agriculture:**
#     *   1. **Precision Farming:** AI for crop monitoring, yield prediction, and resource optimization (water, fertilizer).
#     *   2. **Pest and Disease Detection:** Early identification and management of agricultural threats.
#     *   3. **Supply Chain Optimization:** Improving efficiency from farm to fork.
# *   **C. Finance and Banking (FinTech):**
#     *   1. **Fraud Detection and Risk Management:** AI for enhanced security and compliance.
#     *   2. **Personalized Financial Advice and Robo-Advisors:** Democratizing financial planning.
#     *   3. **Credit Scoring and Loan Underwriting:** Improving access to credit.
#     *   4. **Customer Service (Chatbots):** Enhancing customer experience and operational efficiency.
# *   **D. E-commerce and Retail:**
#     *   1. **Personalized Recommendations and Customer Experience:** Driving sales and engagement.
#     *   2. **Inventory Management and Supply Chain Logistics:** Optimizing operations.
#     *   3. **Demand Forecasting:** Predicting consumer behavior and market trends.
# *   **E. Manufacturing and Industry 4.0:**
#     *   1. **Predictive Maintenance:** Reducing downtime and optimizing equipment performance.
#     *   2. **Quality Control and Automation:** Enhancing product quality and efficiency.
#     *   3. **Robotics and Smart Factories:** Creating more intelligent and agile manufacturing processes.
# *   **F. Education:**
#     *   1. **Personalized Learning Platforms:** Tailoring educational content to individual student needs.
#     *   2. **Automated Grading and Feedback:** Freeing up educators' time.
#     *   3. **AI-powered Tutoring and Skill Development:** Bridging skill gaps.
# *   **G. Transportation and Smart Cities:**
#     *   1. **Traffic Management and Optimization:** Reducing congestion and improving flow.
#     *   2. **Autonomous Vehicles (Future Potential):** Discussing the long-term vision.
#     *   3. **Smart Infrastructure and Urban Planning:** Using AI for better city management.
#
# **IV. The Challenges and Ethical Considerations**
#
# *   **A. Data Privacy and Security:**
#     *   1. **Concerns over data breaches and misuse.**
#     *   2. **Need for robust data protection regulations.**
# *   **B. Bias and Fairness in AI Algorithms:**
#     *   1. **Potential for perpetuating existing societal biases.**
#     *   2. **Importance of developing inclusive and equitable AI.**
# *   **C. Job Displacement and the Future of Work:**
#     *   1. **Concerns about automation replacing human jobs.**
#     *   2. **The need for reskilling and upskilling initiatives.**
#     *   3. **Focus on human-AI collaboration.**
# *   **D. Infrastructure and Accessibility Gaps:**
#     *   1. **Digital divide and uneven access to technology.**
#     *   2. **Ensuring AI benefits reach all sections of society.**
# *   **E. Ethical Governance and Regulation:**
#     *   1. **Developing clear ethical guidelines for AI development and deployment.**
#     *   2. **The role of regulatory bodies in overseeing AI.**
#
# **V. The Road Ahead: India's AI Future**
#
# *   **A. Emerging Trends and Innovations:**
#     *   1. **Generative AI and its potential applications.**
#     *   2. **Edge AI and its impact on real-time processing.**
#     *   3. **AI for sustainability and climate action.**
# *   **B. India's Role in the Global AI Landscape:**
#     *   1. **Becoming a hub for AI research and development.**
#     *   2. **Exporting AI solutions and expertise.**
#     *   3. **Collaborating with international partners.**
# *   **C. The Vision for an AI-Powered India:**
#     *   1. **A more efficient, equitable, and prosperous nation.**
#     *   2. **Leveraging AI for societal good and sustainable development.**
#     *   3. **Empowering citizens through intelligent technologies.**
#
# **VI. Conclusion: Embracing the Intelligent Revolution**
#
# *   **A. Recap of Key Points:** Briefly reiterate the main drivers, impacts, and challenges of AI in India.
# *   **B. Reiterate Thesis:** Emphasize the transformative nature of AI's rise in India.
# *   **C. Call to Action/Final Thought:** Encourage readers to engage with the topic, learn more, or consider the implications of AI for their own lives and communities.
#     *   *Example Call to Action:* "The rise of AI in India is not just a technological advancement; it's a societal evolution. By understanding its potential and addressing its challenges, we can collectively shape a future where AI empowers every Indian."
# *   **D. Engaging Question for Readers:** Prompt discussion in the comments section.
#     *   *Example Question:* "What sector do you believe will be most profoundly impacted by AI in India in the next decade, and why?"
#
# **VII. Additional Elements (Optional but Recommended):**
#
# *   **Infographics/Visuals:** Data visualizations, charts, or images to illustrate key points.
# *   **Case Studies:** Short, impactful examples of Indian companies or organizations successfully implementing AI.
# *   **Expert Quotes:** Insights from AI researchers, industry leaders, or policymakers.
# *   **Glossary of AI Terms:** For readers less familiar with the jargon.
# *   **Further Reading/Resources:** Links to relevant reports, articles, or websites.

# %%
print(final_state['content'])
# Out:
# ## The Rise of AI in India: A Transformative Journey
#
# **I. Introduction: The Dawn of an Intelligent Era in India**
#
# From smart assistants orchestrating our daily routines to AI-powered diagnostics revolutionizing healthcare, Artificial Intelligence is no longer a distant dream for India; it's a rapidly unfolding reality. We are witnessing a profound shift, an intelligent revolution that is poised to redefine how we live, work, and interact with the world around us.
#
# At its core, Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems. These processes include learning (the acquisition of information and rules for using the information), reasoning (using rules to reach approximate or definite conclusions), and self-correction. AI systems can analyze vast amounts of data, identify patterns, solve complex problems, and make decisions, often with a speed and accuracy that surpasses human capabilities.
#
# This blog will delve into the significant and transformative rise of AI adoption and development in India. Driven by a confluence of strategic government initiatives, a burgeoning tech ecosystem, and the sheer scale of digital transformation, AI is rapidly reshaping India's economic landscape and societal fabric. We will explore the key catalysts fueling this growth, examine AI's impact across various critical sectors, acknowledge the inherent challenges and ethical considerations, and finally, envision the promising road ahead for an AI-powered India.
#
# **II. The Catalysts: Why India is Embracing AI**
#
# Several powerful forces are converging to propel India into the AI era. Understanding these catalysts is crucial to appreciating the depth and breadth of this transformation.
#
# **A. Government Initiatives and Policy Support:**
#
# The Indian government has recognized AI's potential as a game-changer and has actively fostered its growth. The **National Strategy for AI**, spearheaded by NITI Aayog, outlines a vision for leveraging AI for inclusive growth and societal benefit. This strategy emphasizes a "AI for All" approach, aiming to democratize AI's advantages across various sectors. Beyond strategy, tangible support comes in the form of **funding and investment** through grants, R&D incentives, and programs designed to nurture AI startups. Initiatives like **Digital India** have laid the foundational digital infrastructure, creating an environment ripe for AI innovation.
#
# **B. Thriving Tech Ecosystem and Talent Pool:**
#
# India boasts a dynamic and rapidly expanding **startup culture**, with a growing number of entrepreneurs focusing on developing innovative AI solutions. This vibrant ecosystem is fueled by a **skilled workforce**. India possesses a large, young, and increasingly proficient talent pool in STEM fields, with a growing number of graduates specializing in AI and machine learning. Furthermore, **educational institutions** are playing a pivotal role, with universities and research centers actively engaged in cutting-edge AI research and producing the next generation of AI experts.
#
# **C. Digital Transformation and Data Availability:**
#
# The widespread adoption of the internet and smartphones has led to an unprecedented surge in **digital access and usage** across India. This digital explosion, coupled with initiatives like **Aadhaar** (unique digital identity) and **UPI** (Unified Payments Interface), has created a rich and vast **data infrastructure**. The sheer volume of **growing data** generated daily from various sources – transactions, social media, sensor networks – provides the essential fuel for training and refining AI algorithms.
#
# **D. Economic Imperatives and Global Competitiveness:**
#
# India faces significant economic challenges, and AI offers a powerful pathway to achieving **efficiency and productivity gains**. By automating tasks, optimizing processes, and enabling data-driven decision-making, AI can unlock new levels of economic growth. In the global arena, India is keen to participate in the **global AI race**, aiming to establish itself as a leader in AI research, development, and deployment. This ambition not only drives domestic innovation but also makes India an attractive destination for **attracting foreign investment** from global tech giants looking to tap into its talent and market potential.
#
# **III. AI in Action: Transforming Key Sectors in India**
#
# The impact of AI is not confined to theoretical discussions; it is actively transforming industries across the Indian economy.
#
# **A. Healthcare:**
#
# AI is revolutionizing healthcare by enabling **diagnostics and imaging** for early disease detection, such as identifying cancerous tumors or diabetic retinopathy with remarkable accuracy. It is accelerating **drug discovery and development**, leading to more personalized and effective treatments. **Robotic surgery** is enhancing surgical precision, while AI-powered tools are improving patient care and monitoring. Furthermore, AI is bridging geographical divides through **telemedicine and remote healthcare** solutions, bringing quality medical services to rural and underserved populations.
#
# **B. Agriculture:**
#
# In a nation where agriculture is a cornerstone of the economy, AI is ushering in an era of **precision farming**. AI algorithms analyze data from sensors and drones to optimize resource allocation for crops, predict yields, and manage water and fertilizer usage efficiently. It aids in the early detection and management of **pests and diseases**, safeguarding harvests. AI also plays a crucial role in **supply chain optimization**, ensuring that produce reaches consumers efficiently from farm to fork.
#
# **C. Finance and Banking (FinTech):**
#
# The financial sector is a prime beneficiary of AI. **Fraud detection and risk management** systems are becoming more sophisticated, enhancing security and compliance. AI-powered **personalized financial advice and robo-advisors** are democratizing financial planning, making it accessible to a wider audience. AI is also improving **credit scoring and loan underwriting**, potentially increasing access to credit for individuals and small businesses. **Chatbots** are transforming customer service, providing instant support and improving operational efficiency.
#
# **D. E-commerce and Retail:**
#
# AI is at the heart of the personalized experiences offered by e-commerce platforms. **Personalized recommendations** drive sales and customer engagement, while AI optimizes **inventory management and supply chain logistics**. **Demand forecasting** powered by AI helps retailers anticipate consumer behavior and market trends, leading to more effective business strategies.
#
# **E. Manufacturing and Industry 4.0:**
#
# The manufacturing sector is embracing AI to achieve greater efficiency and innovation. **Predictive maintenance** systems use AI to anticipate equipment failures, minimizing downtime and optimizing performance. **Quality control and automation** are being enhanced, leading to improved product quality and faster production cycles. The integration of **robotics and smart factories** is creating more intelligent and agile manufacturing processes.
#
# **F. Education:**
#
# AI is poised to personalize the learning experience. **Personalized learning platforms** tailor educational content to individual student needs and learning paces. **Automated grading and feedback** systems free up educators' time, allowing them to focus on more impactful teaching. **AI-powered tutoring and skill development** tools are emerging to bridge skill gaps and equip individuals for the future workforce.
#
# **G. Transportation and Smart Cities:**
#
# AI is a key enabler of **smart cities**. It is being used to optimize **traffic management and flow**, reducing congestion and travel times. While **autonomous vehicles** are still in their nascent stages, they represent a significant future potential. AI also contributes to **smart infrastructure and urban planning**, enabling better management of city resources and services.
#
# **IV. The Challenges and Ethical Considerations**
#
# Despite the immense potential, the rise of AI in India is not without its hurdles and ethical dilemmas.
#
# **A. Data Privacy and Security:**
#
# The increasing reliance on data for AI raises significant concerns about **data privacy and security**. The potential for data breaches and misuse necessitates the development and enforcement of **robust data protection regulations**.
#
# **B. Bias and Fairness in AI Algorithms:**
#
# AI algorithms are trained on data, and if that data reflects existing societal biases, the AI can perpetuate and even amplify them. Ensuring **inclusive and equitable AI** requires careful attention to data sourcing and algorithm design to avoid discrimination.
#
# **C. Job Displacement and the Future of Work:**
#
# A significant concern is the potential for **automation to replace human jobs**. While AI will create new roles, there is a pressing need for **reskilling and upskilling initiatives** to prepare the workforce for this transition. The focus must shift towards **human-AI collaboration**, where AI augments human capabilities rather than replacing them entirely.
#
# **D. Infrastructure and Accessibility Gaps:**
#
# The **digital divide** remains a reality in India, with uneven access to technology and internet connectivity. Ensuring that the benefits of AI reach all sections of society requires addressing these **infrastructure and accessibility gaps**.
#
# **E. Ethical Governance and Regulation:**
#
# As AI becomes more pervasive, the need for **ethical governance and clear regulatory frameworks** becomes paramount. Developing guidelines for AI development and deployment, and establishing regulatory bodies to oversee its responsible use, are crucial steps.
#
# **V. The Road Ahead: India's AI Future**
#
# The trajectory of AI in India is one of continuous innovation and expanding influence.
#
# **A. Emerging Trends and Innovations:**
#
# We are witnessing the rapid evolution of **generative AI**, with its potential to create new content and revolutionize creative industries. **Edge AI**, enabling real-time processing on devices, will unlock new possibilities in areas like IoT and autonomous systems. Furthermore, AI is increasingly being leveraged for **sustainability and climate action**, offering solutions for environmental monitoring and resource management.
#
# **B. India's Role in the Global AI Landscape:**
#
# India is well-positioned to become a significant hub for **AI research and development**. Its growing expertise and innovative solutions have the potential to be exported globally, establishing India as a key player in the international AI arena. **Collaboration with international partners** will further accelerate this growth and foster global knowledge exchange.
#
# **C. The Vision for an AI-Powered India:**
#
# The ultimate vision is an India that is more **efficient, equitable, and prosperous** through the intelligent application of AI. By leveraging AI for societal good and sustainable development, India can empower its citizens and address its most pressing challenges, creating a future where technology serves humanity.
#
# **VI. Conclusion: Embracing the Intelligent Revolution**
#
# The rise of AI in India is a multifaceted phenomenon, driven by strategic government support, a vibrant tech ecosystem, and the pervasive digital transformation. Its impact is already being felt across critical sectors, promising enhanced efficiency, improved services, and new avenues for growth. However, navigating this transformative journey requires a conscious effort to address the challenges of data privacy, algorithmic bias, job displacement, and equitable access.
#
# The rise of AI in India is not just a technological advancement; it's a societal evolution. By understanding its potential and proactively addressing its challenges, we can collectively shape a future where AI empowers every Indian.
#
# **What sector do you believe will be most profoundly impacted by AI in India in the next decade, and why? Share your thoughts in the comments below!**
